-- %% [markdown]
-- ## Validation Telemetria

-- %%
CREATE OR REPLACE TABLE data_lake_hermes_ai.prata.validation_telemetria AS ( 
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_1
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_2
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_3
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_4
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_5
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_6
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_7
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_8
UNION
SELECT
*
FROM data_lake_hermes_ai.bronze.telemetria_9)

-- %%
SELECT 
*
FROM data_lake_hermes_ai.prata.validation_telemetria
LIMIT 100
