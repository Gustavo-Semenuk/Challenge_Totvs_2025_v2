# %%
import sys
import pandas as pd
import numpy as np
from pyspark.sql import SparkSession
sys.path.append(r"D:\Faculdade\Challenge_Totvs_2025\Hermes.ai")

from ms_analytics.view.view_analytics_s3 import listar_arquivos_disponiveis
from ms_analytics.view.view_analytics_s3 import carregar_arquivo_para_dataframe

listar_arquivos_disponiveis()
# Out:
# Arquivos disponíveis: ['Challenge_TOTVS_2025_MassaDados_v1/clientes_desde.csv', 'Challenge_TOTVS_2025_MassaDados_v1/contratacoes_ultimos_12_meses.csv', 'Challenge_TOTVS_2025_MassaDados_v1/dados_clientes.csv', 'Challenge_TOTVS_2025_MassaDados_v1/export.csv', 'Challenge_TOTVS_2025_MassaDados_v1/historico.csv', 'Challenge_TOTVS_2025_MassaDados_v1/mrr.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_relacional.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_aquisicao.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_implantacao.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_onboarding.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_produto.csv', 'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_suporte.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_1.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_10.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_11.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_2.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_3.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_4.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_5.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_6.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_7.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_8.csv', 'Challenge_TOTVS_2025_MassaDados_v1/telemetria_9.csv', 'Challenge_TOTVS_2025_MassaDados_v1/tickets.csv']
# ['Challenge_TOTVS_2025_MassaDados_v1/clientes_desde.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/contratacoes_ultimos_12_meses.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/dados_clientes.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/export.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/historico.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/mrr.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_relacional.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_aquisicao.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_implantacao.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_onboarding.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_produto.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/nps_transacional_suporte.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_1.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_10.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_11.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_2.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_3.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_4.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_5.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_6.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_7.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_8.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/telemetria_9.csv',
#  'Challenge_TOTVS_2025_MassaDados_v1/tickets.csv']

# %%
arquivo = carregar_arquivo_para_dataframe('Challenge_TOTVS_2025_MassaDados_v1/export.csv')
arquivo
# Out:
#      CD_CLIENTE                       DS_PROD               DS_LIN_REC  \
# 0        T00053       SMS COLAB NEO  2500 DOC        SMS TOTVS SERIE T
# 1        T00053                  HORA SUPORTE  CONSULTORIA TRADICIONAL
# 2        T00053          PROGRESS USER 11 CDU        CDU TOTVS SERIE T
# 3        T00053          PROGRESS USER 11 CDU        CDU TOTVS SERIE T
# 4        T00053  CDU LGT GCH ON-DEMAND 10 ALG         SAAS CDU ALUGUEL
# ...         ...                           ...                      ...
# 5897     T02904            SMS TOTVS TEC USER        SMS TOTVS SERIE T
# 5898     T05114  HELP DESK ERP/CRM/BI TR/FULL        SMS TOTVS SERIE T
# 5899     T04305            SMS TOTVS TEC USER        SMS TOTVS SERIE T
# 5900     T06381  CONTRATO MENSAL MY AUDIT REC             SAAS SERIE T
# 5901     T07544   CONSINCO ERP BACKOFFICE CDU        CDU TOTVS SERIE T
#
#             CIDADE                                            DS_CNAE  \
# 0     RIODEJANEIRO            Fabricacao de preparacoes farmaceuticas
# 1     RIODEJANEIRO            Fabricacao de preparacoes farmaceuticas
# 2     RIODEJANEIRO            Fabricacao de preparacoes farmaceuticas
# 3     RIODEJANEIRO            Fabricacao de preparacoes farmaceuticas
# 4     RIODEJANEIRO            Fabricacao de preparacoes farmaceuticas
# ...            ...                                                ...
# 5897  RIODEJANEIRO  Fabricacao de materiais para medicina e odonto...
# 5898  RIODEJANEIRO       Organizacao logistica do transporte de carga
# 5899      SAOPAULO  Comercio atacadista de medicamentos e drogas d...
# 5900      CABEDELO  Comercio atacadista de materiais de construcao...
# 5901         BETIM  Comercio atacadista de mercadorias em geral, s...
#
#      DS_SEGMENTO              DS_SUBSEGMENTO                       FAT_FAIXA  \
# 0     MANUFATURA               BENS DURAVEIS     Faixa 05 - De 35 M ate 50 M
# 1     MANUFATURA               BENS DURAVEIS     Faixa 05 - De 35 M ate 50 M
# 2     MANUFATURA               BENS DURAVEIS     Faixa 05 - De 35 M ate 50 M
# 3     MANUFATURA               BENS DURAVEIS     Faixa 05 - De 35 M ate 50 M
# 4     MANUFATURA               BENS DURAVEIS     Faixa 05 - De 35 M ate 50 M
# ...          ...                         ...                             ...
# 5897  MANUFATURA               BENS DURAVEIS  Sem Informações de Faturamento
# 5898   LOGISTICA               TRANSPORTADOR     Faixa 03 - De 15 M ate 25 M
# 5899  MANUFATURA             BENS DE CONSUMO    Faixa 07 - De 75 M ate 150 M
# 5900      VAREJO      MATERIAL DE CONSTRUCAO   Faixa 01 - De 4,5 M ate 7,5 M
# 5901      VAREJO  CONCESSIONARIA DE VEICULOS     Faixa 06 - De 50 M ate 75 M
#
#                        MARCA_TOTVS                         MODAL_COMERC  PAIS  \
# 0            MANUFATURA - PARCEIRO               MODALIDADE TRADICIONAL   105
# 1          SERVICOS DE IMPLANTACAO  MODALIDADE SERVICOS NÃO RECORRENTES   105
# 2                         PROGRESS               MODALIDADE TRADICIONAL   105
# 3                         PROGRESS               MODALIDADE TRADICIONAL   105
# 4                        RH - CORE          MODALIDADE ALUGUEL (LEGADO)   105
# ...                            ...                                  ...   ...
# 5897                    TECNOLOGIA               MODALIDADE TRADICIONAL   105
# 5898           CROSS - TRADICIONAL               MODALIDADE TRADICIONAL   105
# 5899                    TECNOLOGIA               MODALIDADE TRADICIONAL   105
# 5900  DISTRIBUICAO & VAREJO - CORE   MODALIDADE ASSINATURA COMPLEMENTAR   105
# 5901          SUPERMERCADOS - CORE               MODALIDADE TRADICIONAL   105
#
#      PERIODICIDADE SITUACAO_CONTRATO  UF   VL_TOTAL_CONTRATO  \
# 0      00 - Mensal             ATIVO  RJ    341,155636978792
# 1      00 - Mensal         CANCELADO  RJ    45,3386017130146
# 2      00 - Mensal           TROCADO  RJ   0,117708006301753
# 3      00 - Mensal           TROCADO  RJ    5278,00598328378
# 4      00 - Mensal         CANCELADO  RJ    370,048748668505
# ...            ...               ...  ..                 ...
# 5897   00 - Mensal         CANCELADO  RJ    0,18076586682055
# 5898   00 - Mensal         CANCELADO  RJ    141,165530414746
# 5899   00 - Mensal             ATIVO  SP    3,99366449952377
# 5900   00 - Mensal         CANCELADO  PB    620,001700050278
# 5901   00 - Mensal          GRATUITO  MG  0,0546501457829569
#
#      DT_ASSINATURA_CONTRATO CLIENTE_DESDE  QTD_CONTRATACOES_12M  \
# 0                2015-02-27    1992-02-26                     1
# 1                1997-11-28    1992-02-26                     1
# 2                2017-11-22    1992-02-26                     1
# 3                2010-12-20    1992-02-26                     1
# 4                2010-08-31    1992-02-26                     1
# ...                     ...           ...                   ...
# 5897             2013-10-08    2000-08-11                     1
# 5898             2003-04-28    1999-08-02                     1
# 5899             2022-10-31    1998-12-28                     4
# 5900             2018-02-05    2000-06-28                     3
# 5901             2006-07-01    2006-07-01                     1
#
#      VLR_CONTRATACOES_12M
# 0         4317,9500568851
# 1         4317,9500568851
# 2         4317,9500568851
# 3         4317,9500568851
# 4         4317,9500568851
# ...                   ...
# 5897     5015,21865535775
# 5898     191,077928944057
# 5899     39574,8273992956
# 5900     5693,46900309792
# 5901     2104,64437581956
#
# [5902 rows x 19 columns]
